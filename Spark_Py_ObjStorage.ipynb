# %%
# worked
# !pip install ibmos2spark

# %%
import ibmos2spark as oss

# %%
credentials = {
  'auth_url': 'https://identity.open.softlayer.com',
  'project_id': '01e3daca6350445799264b1c8d5c5c50',
  'region': 'dallas',
  'user_id': '7a87f299fd094e4d9eac9d44f1cae277',
  'username': 'admin_f0c0e2e972c10c047fff8322d08f6faa4b0d1eed',
  'password': 'fufeHVj(^l_W]3!3',
}

# %%
credentials['name'] = 'my_bluemix_os'  #you can give any name you like

bmos = oss.bluemix2d(sc, credentials)  #sc is the SparkContext instance

data = sc.textFile(bmos.url('notebooks_spark', 'Consumer_Complaints_100.csv'))

# %%
data.count()
# Out:
# 435

# %%
data.take(5)
# Out:
# [u'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00;H\ufffd@i\x01\x00\x00\ufffd\x04\x00\x00\x13\x00\x08\x02[Content_Types].xml \ufffd\x04\x02(\ufffd\x0
# ...
